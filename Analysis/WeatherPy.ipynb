# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
coordinates
# Out:
# [(-67.80031911555487, 88.22167422567372),
#  (46.08856168202968, 82.87231697294993),
#  (1.8521484208511367, -55.9874623066689),
#  (5.7151196642809765, 79.32580442581218),
#  (-56.328419797939844, 82.87701350773932),
#  (-37.67426189415697, -92.47620546424437),
#  (-87.63852419706055, 39.07755873797845),
#  (57.444609450616184, -75.68903328469949),
#  (5.083277118708651, -85.69498181930483),
#  (-79.76035298156951, -29.02322854569897),
#  (31.305193070805174, -31.333947002532256),
#  (-6.197457033037409, 171.46895515717176),
#  (5.692659686884724, -67.61302808367716),
#  (49.51235757941089, 158.475420157001),
#  (61.98420777198578, 171.38830482899323),
#  (80.08735244517095, 144.4701414210715),
#  (21.855480196852696, 0.31076691041872095),
#  (-40.40724302777831, 136.071657071559),
#  (-56.48226409212495, -0.40618931937436287),
#  (-74.42827691759254, -22.047500385909927),
#  (-46.58105142729101, -7.232920331229991),
#  (-71.66884304801971, -23.753521703148124),
# ...

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# busselton au
# urdzhar kz
# grand-santi gf
# galle lk
# busselton au
# lebu cl
# port elizabeth za
# chapais ca
# burica pa
# ushuaia ar
# ribeira grande pt
# lolua tv
# puerto ayacucho ve
# severo-kurilsk ru
# kamenskoye ru
# chokurdakh ru
# tessalit ml
# mount gambier au
# cape town za
# ushuaia ar
# saldanha za
# ushuaia ar
# belushya guba ru
# bilibino ru
# mys shmidta ru
# ziniare bf
# bredasdorp za
# lebu cl
# mount isa au
# jatai br
# airai pw
# bluff nz
# atuona pf
# quatre cocos mu
# mataura pf
# mataura pf
# kantunilkin mx
# aflu dz
# malinao ph
# ringas in
# punta arenas cl
# punta arenas cl
# jamestown sh
# new norfolk au
# ushuaia ar
# bethel us
# praia cv
# port alfred za
# dikson ru
# busselton au
# hobart au
# ugoofaaru mv
# beringovskiy ru
# port alfred za
# punta arenas cl
# fukue jp
# vaini to
# georgetown sh
# bengkulu id
# bamenda cm
# saint george bm
# hithadhoo mv
# cairns au
# kapaa us
# ryotsu jp
# hilo us
# pangnirtung ca
# artyk ru
# karratha au
# ...

# %%
# Create a list for holding the cities.
cities = []

# %%
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 629

# %%
# import dependencies and api key
import requests
from config import weather_api_key

# %%
# Build Basic url + api key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | urdzhar
# City not found. Skipping...
# Processing Record 3 of Set 1 | grand-santi
# Processing Record 4 of Set 1 | galle
# Processing Record 5 of Set 1 | lebu
# Processing Record 6 of Set 1 | port elizabeth
# Processing Record 7 of Set 1 | chapais
# Processing Record 8 of Set 1 | burica
# City not found. Skipping...
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | ribeira grande
# Processing Record 11 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 1 | puerto ayacucho
# Processing Record 13 of Set 1 | severo-kurilsk
# Processing Record 14 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 1 | chokurdakh
# Processing Record 16 of Set 1 | tessalit
# Processing Record 17 of Set 1 | mount gambier
# Processing Record 18 of Set 1 | cape town
# ...

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Busselton -33.6500  115.3333     62.01        84          97
# 1      Grand-Santi   4.2500  -54.3833     77.38        88         100
# 2            Galle   6.0367   80.2170     81.25        84          27
# 3             Lebu -37.6167  -73.6500     59.99        79          45
# 4   Port Elizabeth -33.9180   25.5701     64.40        82           0
# 5          Chapais  49.7834  -74.8492     17.60        29           1
# 6          Ushuaia -54.8000  -68.3000     48.20        76           0
# 7   Ribeira Grande  38.5167  -28.7000     60.80        88          75
# 8  Puerto Ayacucho   5.6639  -67.6236     89.76        52          97
# 9   Severo-Kurilsk  50.6789  156.1250     27.73        82          60
#
#    Wind Speed Country                 Date
# 0        1.01      AU  2021-04-02 15:55:37
# 1        1.72      GF  2021-04-02 15:55:37
# 2       10.54      LK  2021-04-02 15:55:38
# ...

# %%
# Re-order the columns 
new_column_order = ["City", "Country","Date","Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                City Country                 Date      Lat       Lng  Max Temp  \
# 0         Busselton      AU  2021-04-02 15:55:37 -33.6500  115.3333     62.01
# 1       Grand-Santi      GF  2021-04-02 15:55:37   4.2500  -54.3833     77.38
# 2             Galle      LK  2021-04-02 15:55:38   6.0367   80.2170     81.25
# 3              Lebu      CL  2021-04-02 15:55:38 -37.6167  -73.6500     59.99
# 4    Port Elizabeth      ZA  2021-04-02 15:54:52 -33.9180   25.5701     64.40
# ..              ...     ...                  ...      ...       ...       ...
# 564         Tzaneen      ZA  2021-04-02 15:58:57 -23.8332   30.1635     69.80
# 565         Parabel      RU  2021-04-02 15:58:58  58.6978   81.4825     32.68
# 566         Northam      GB  2021-04-02 15:58:58  51.0333   -4.2167     54.00
# 567        Teguldet      RU  2021-04-02 15:58:59  57.3064   88.1667     29.14
# 568            Sola      VU  2021-04-02 15:58:59 -13.8833  167.5500     81.91
#
# ...

# %%
# Create the output file (CSV).
output_data_file = "cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# %%
# %matplotlib notebook

# %%
# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("Fig1_lat_vs_maxtemp.png")

# Show plot.
plt.show()
# Out:
# <img src="data:," width="0">

# %%
# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity %")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("Fig2_lat_vs_humidity.png")

# Show plot.
plt.show()
# Out:
# <img src="data:," width="0">

# %%
# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("Fig3_lat_vs_cloudiness.png")

# Show plot.
plt.show()
# Out:
# <img src="data:," width="0">

# %%
# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("Fig4_lat_vs_windspeed.png")

# Show plot.
plt.show()
# Out:
# <img src="data:," width="0">

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
# Review .loc
index13 = city_data_df.loc[13]
index13
# Out:
# City                    Cape Town
# Country                        ZA
# Date          2021-04-02 15:54:52
# Lat                      -33.9258
# Lng                       18.4232
# Max Temp                     69.8
# Humidity                       56
# Cloudiness                      0
# Wind Speed                   11.5
# Name: 13, dtype: object

# %%
# Northern Hemisphere Data
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
northern_hemi_df.head(10)
# Out:
#                City Country                 Date      Lat       Lng  Max Temp  \
# 1       Grand-Santi      GF  2021-04-02 15:55:37   4.2500  -54.3833     77.38
# 2             Galle      LK  2021-04-02 15:55:38   6.0367   80.2170     81.25
# 5           Chapais      CA  2021-04-02 15:55:38  49.7834  -74.8492     17.60
# 7    Ribeira Grande      PT  2021-04-02 15:55:39  38.5167  -28.7000     60.80
# 8   Puerto Ayacucho      VE  2021-04-02 15:55:40   5.6639  -67.6236     89.76
# 9    Severo-Kurilsk      RU  2021-04-02 15:55:40  50.6789  156.1250     27.73
# 10       Chokurdakh      RU  2021-04-02 15:55:40  70.6333  147.9167     -1.91
# 11         Tessalit      ML  2021-04-02 15:55:41  20.1986    1.0114     94.33
# 15         Bilibino      RU  2021-04-02 15:55:42  68.0546  166.4372    -10.39
# 16          Ziniare      BF  2021-04-02 15:55:43  12.5822   -1.2983    102.20
#
#     Humidity  Cloudiness  Wind Speed
# 1         88         100        1.72
# ...

# %%
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]
southern_hemi_df.head(10)
# Out:
#               City Country                 Date      Lat       Lng  Max Temp  \
# 0        Busselton      AU  2021-04-02 15:55:37 -33.6500  115.3333     62.01
# 3             Lebu      CL  2021-04-02 15:55:38 -37.6167  -73.6500     59.99
# 4   Port Elizabeth      ZA  2021-04-02 15:54:52 -33.9180   25.5701     64.40
# 6          Ushuaia      AR  2021-04-02 15:55:39 -54.8000  -68.3000     48.20
# 12   Mount Gambier      AU  2021-04-02 15:55:41 -37.8333  140.7667     55.40
# 13       Cape Town      ZA  2021-04-02 15:54:52 -33.9258   18.4232     69.80
# 14        Saldanha      ZA  2021-04-02 15:55:42 -33.0117   17.9442     71.60
# 17      Bredasdorp      ZA  2021-04-02 15:55:43 -34.5322   20.0403     69.80
# 18       Mount Isa      AU  2021-04-02 15:55:43 -20.7333  139.5000     73.40
# 19           Jatai      BR  2021-04-02 15:53:45 -17.8814  -51.7144     89.74
#
#     Humidity  Cloudiness  Wind Speed
# 0         84          97        1.01
# 3         79          45       14.61
# ...

# %%
# Linear regression on the Northern Hemisphere
# set x & y values to equal latitude column, and max temp column 
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

x_values
# Out:
# 1       4.2500
# 2       6.0367
# 5      49.7834
# 7      38.5167
# 8       5.6639
#         ...
# 562    62.6323
# 563    65.8252
# 565    58.6978
# 566    51.0333
# 567    57.3064
# Name: Lat, Length: 372, dtype: float64

# %%
y_values
# Out:
# 1      77.38
# 2      81.25
# 5      17.60
# 7      60.80
# 8      89.76
#        ...
# 562    44.01
# 563    42.80
# 565    32.68
# 566    54.00
# 567    29.14
# Name: Max Temp, Length: 372, dtype: float64

# %%
# Call the function.
plot_linear_regression(x_values, y_values,'Linear Regression on the Northern Hemisphere for Maximum Temperature', 'Max Temp',(10,-20))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
linregress(x_values, y_values)
# Out:
# LinregressResult(slope=-1.2429716034935243, intercept=99.67276204223774, rvalue=-0.8667124769568694, pvalue=8.216114361719934e-114, stderr=0.037189364762590785)

# %%
# Linear regression on the Southern Hemisphere Temp
x_values_2 = southern_hemi_df["Lat"]
y_values_2 = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values_2,'Linear Regression on the Southern Hemisphere for Maximum Temperature', 'Max Temp',(-30,50))
# Out:
# <img src="data:," width="0">

# %%
linregress(x_values_2, y_values_2)
# Out:
# LinregressResult(slope=0.5407974534600803, intercept=86.01825947778374, rvalue=0.7051482720229447, pvalue=6.152507186570367e-31, stderr=0.03894213872168424)

# %%
# Linear regression on the Northern Hemisphere Humidity
x_values = northern_hemi_df["Lat"]
y_values_humidity = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values_humidity,'Linear Regression on the Northern Hemisphere for Humidity', 'Humidity(%)',(45,10))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
linregress(x_values, y_values_humidity)
# Out:
# LinregressResult(slope=0.4710980958212403, intercept=44.839361531176166, rvalue=0.35333387974949493, pvalue=2.2246673801311315e-12, stderr=0.06484369223599333)

# %%
# Linear regression on the Southern Hemisphere Humidity
y_values_humidity2 = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values_2, y_values_humidity2,'Linear Regression on the Southern Hemisphere for Humidity', 'Humidity(%)',(-55,30))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
linregress(x_values_2, y_values_humidity2)
# Out:
# LinregressResult(slope=0.2509933203927667, intercept=75.00780447940082, rvalue=0.1901118209385045, pvalue=0.007454805287430693, stderr=0.09282012545868788)

# %%
# Linear regression on the Northern Hemisphere Cloudiness
y_values_cloud = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values_cloud ,'Linear Regression on the Northern Hemisphere for % Cloudiness', 'Cloudiness(%)',(50,30))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
linregress(x_values, y_values_cloud)
# Out:
# LinregressResult(slope=0.5832720013672505, intercept=27.812850469612137, rvalue=0.2944124891108574, pvalue=7.118942885745587e-09, stderr=0.09842962451298218)

# %%
# Linear regression on the Southern Hemisphere
x_values_2 = southern_hemi_df["Lat"]
y_values_cloud2 = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values_2, y_values_cloud2,
                       'Linear Regression on the Southern Hemisphere for % Cloudiness', '% Cloudiness',(-50,60))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
linregress(x_values_2, y_values_cloud2)
# Out:
# LinregressResult(slope=0.7372913891008998, intercept=65.85918954163373, rvalue=0.26593456046548186, pvalue=0.00015869245902853262, stderr=0.19139037431159686)

# %%
# Linear regression on the Northern Hemisphere Wind Speed
x_values = northern_hemi_df["Lat"]
y_values_wind = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values_wind,
                       'Linear Regression on the Northern Hemisphere for Wind Speed', 'Wind Speed (mph)',(10,30))
# Out:
# <img src="data:," width="0">

# %%
linregress(x_values, y_values_wind)
# Out:
# LinregressResult(slope=0.029872267086314526, intercept=7.511464817960712, rvalue=0.10945501803594013, pvalue=0.034829809488040674, stderr=0.014103094778020065)

# %%
# Linear regression on the Southern Hemisphere Wind Speed
x_values_2 = southern_hemi_df["Lat"]
y_values_wind2 = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values_2, y_values_wind2,
                       'Linear Regression on the Southern Hemisphere for Wind Speed', 'Wind Speed (mph)',(-50,25))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
linregress(x_values_2, y_values_wind2)
# Out:
# LinregressResult(slope=-0.07803921068166689, intercept=6.2218245783483415, rvalue=-0.19787921068245978, pvalue=0.0053147989858767205, stderr=0.027683550772538534)
